# %% [markdown]
# <a href="https://colab.research.google.com/github/OmDesai0/Python/blob/main/Expriment12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
file_path = '/content/POPH.csv'
df = pd.read_csv(file_path)

# %%
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)
df = df.sort_index()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['value'], label='Population')
plt.title('Population Over Time')
plt.xlabel('Year')
plt.ylabel('Population')
plt.grid(True)
plt.legend()
plt.show()
